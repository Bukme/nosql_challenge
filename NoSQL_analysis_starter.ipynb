# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from bson import SON

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collection_names = db.list_collection_names()
pprint(collection_names)
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}
result = establishments.find(query)

# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(query)
print(f"Number of establishments with a hygiene score of 20: {count_documents}")

# Display the first document in the results using pprint
if count_documents > 0:
    first_document = next(result)
    print("\nFirst document:")
    pprint(first_document)
else:
    print("No establishments found with a hygiene score of 20.")
# Out:
# Number of establishments with a hygiene score of 20: 41
#
# First document:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889574a11a2a0c921a05'),
#  'geocode': {'latitude': {'$toDouble': '$geocode.latitude'},
#              'longitude': {'$toDouble': '$geocode.longitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df_result = pd.DataFrame(result)

# Display the number of rows in the DataFrame
num_rows = len(df_result)
print(f"Number of rows in the DataFrame: {num_rows}")

# Display the first 10 rows of the DataFrame
print(df_result.head(10))
# Out:
# Number of rows in the DataFrame: 40
#                         _id   FHRSID  ChangesByServerID  \
# 0  6595889574a11a2a0c921d84   612039                  0
# 1  6595889574a11a2a0c92209c   730933                  0
# 2  6595889574a11a2a0c92227d   172735                  0
# 3  6595889574a11a2a0c92228d   172953                  0
# 4  6595889574a11a2a0c922c2c   512854                  0
# 5  6595889574a11a2a0c922e4a  1537089                  0
# 6  6595889674a11a2a0c924376   155648                  0
# 7  6595889674a11a2a0c9247bc  1012883                  0
# 8  6595889674a11a2a0c924fce   644109                  0
# 9  6595889674a11a2a0c92503e   267034                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                1970/FOOD                 Brenalwood
# 1                1698/FOOD              Melrose Hotel
# 2             PI/000023858              Seaford Pizza
# 3             PI/000024532              Golden Palace
# 4            12/00816/BUTH           Ashby's Butchers
# 5          22/00224/RESTUN  South Sea Express Cuisine
# 6              EH/00006058              Golden Palace
# 7         17/00110/MIXED/S             The Tulip Tree
# 8                    41811                      F & S
# 9           11/00102/MIXED                  Longhouse
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5              Hall Lane
# 1  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 2             Takeaway/sandwich shop            7844          4 High Street
# 3            Restaurant/Cafe/Canteen               1         5 South Street
# 4                  Retailers - other            4613   777 Southchurch Road
# 5            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 6             Takeaway/sandwich shop            7844          7 London Road
# 7            Restaurant/Cafe/Canteen               1          3 The Village
# 8                  Retailers - other            4613
# 9            Restaurant/Cafe/Canteen               1         17 London Road
#
#          AddressLine2 AddressLine3  ...                LocalAuthorityWebSite  \
# 0  Walton-on-the-Naze        Essex  ...        http://www.tendringdc.gov.uk/
# 1      Clacton On Sea        Essex  ...        http://www.tendringdc.gov.uk/
# 2             Seaford  East Sussex  ...  http://www.lewes-eastbourne.gov.uk/
# 3             Seaford  East Sussex  ...  http://www.lewes-eastbourne.gov.uk/
# 4     Southend-On-Sea        Essex  ...           http://www.southend.gov.uk
# 5     Southend-on-sea        Essex  ...           http://www.southend.gov.uk
# 6            Rayleigh        Essex  ...           http://www.rochford.gov.uk
# 7       Chiddingstone         KENT  ...         http://www.sevenoaks.gov.uk/
# 8      81 Southernhay     Basildon  ...           http://www.basildon.gov.uk
# 9           Riverhead         KENT  ...         http://www.sevenoaks.gov.uk/
#
#               LocalAuthorityEmailAddress  \
# 0             fhsadmin@tendringdc.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2    ehealth.ldc@lewes-eastbourne.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    EnvironmentalHealth@southend.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6       customerservices@rochford.gov.uk
# 7  environmental.health@sevenoaks.gov.uk
# 8                    ehs@basildon.gov.uk
# 9  environmental.health@sevenoaks.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 9  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': {'$toDouble': '$geocode.longitud...
# 1  {'longitude': {'$toDouble': '$geocode.longitud...
# 2  {'longitude': {'$toDouble': '$geocode.longitud...
# 3  {'longitude': {'$toDouble': '$geocode.longitud...
# 4  {'longitude': {'$toDouble': '$geocode.longitud...
# 5  {'longitude': {'$toDouble': '$geocode.longitud...
# 6  {'longitude': {'$toDouble': '$geocode.longitud...
# 7  {'longitude': {'$toDouble': '$geocode.longitud...
# 8  {'longitude': {'$toDouble': '$geocode.longitud...
# 9  {'longitude': {'$toDouble': '$geocode.longitud...
#
#       Distance NewRatingPending  \
# 0  4617.965824            False
# 1  4619.656144            False
# 2  4620.421725            False
# 3  4620.437179            False
# 4  4625.565258            False
# 5  4626.200132            False
# 6  4632.276890            False
# 7  4633.934041            False
# 8  4636.552523            False
# 9  4636.703065            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    'LocalAuthorityName': {'$regex': 'london', '$options': 'i'},
    'RatingValue': {'$gte': 4}
}


# Find the establishments with the specified criteria
result = establishments.find(query)

# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(query)
print(f"Number of establishments with London as Local Authority and RatingValue >= 4: {count_documents}")

# Display the first document in the results using pprint
if count_documents > 0:
    first_document = next(result)
    print("\nFirst document:")
    pprint(first_document)
else:
    print("No establishments found with London as Local Authority and RatingValue >= 4.")
# Out:
# Number of establishments with London as Local Authority and RatingValue >= 4: 34
#
# First document:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889574a11a2a0c923422'),
#  'geocode': {'latitude': {'$toDouble': '$geocode.latitude'},
#              'longitude': {'$toDouble': '$geocode.longitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
num_rows = len(df)
print(f"Number of rows in the DataFrame: {num_rows}")

# Display the first 10 rows of the DataFrame
print("\nFirst 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 33
#
# First 10 rows of the DataFrame:
#                         _id     FHRSID  ChangesByServerID  \
# 0  6595889574a11a2a0c923744  1130836.0                0.0
# 1  6595889674a11a2a0c924291   293783.0                0.0
# 2  6595889674a11a2a0c925093  1315095.0                0.0
# 3  6595889674a11a2a0c92509b   294474.0                0.0
# 4  6595889674a11a2a0c92579c   294900.0                0.0
# 5  6595889674a11a2a0c9278b2   293756.0                0.0
# 6  6595889774a11a2a0c927c70   878523.0                0.0
# 7  6595889774a11a2a0c927c8b   293772.0                0.0
# 8  6595889774a11a2a0c927c8c   294606.0                0.0
# 9  6595889774a11a2a0c927c8d   295107.0                0.0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000034075               Mv City Cruises Erasmus
# 1             PI/000002614             Benfleet Motor Yacht Club
# 2             PI/000036464  Coombs Catering t/a The Lock and Key
# 3             PI/000014647              Tilbury Seafarers Centre
# 4             PI/000019066                            Mv Valulla
# 5             PI/000002538                         Tereza Joanne
# 6             PI/000029844                      Brick Lane Brews
# 7             PI/000002585         The Nuance Group (UK) Limited
# 8             PI/000016185                              WH Smith
# 9             PI/000020749                      City Bar & Grill
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Restaurant/Cafe/Canteen               1
# 3  Restaurant/Cafe/Canteen               1
# 4  Other catering premises            7841
# 5  Other catering premises            7841
# 6  Restaurant/Cafe/Canteen               1
# 7        Retailers - other            4613
# 8        Retailers - other            4613
# 9  Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1  \
# 0                                 Cherry Garden Pier
# 1                                         Ferry Road
# 2                                  Leslie Ford House
# 3                          Tenants Row Tilbury Docks
# 4  Reeds River Cruises LtdKings ReachRiver Thames...
# 5  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 6                       Air side London City Airport
# 7                  Duty Free Shop Passenger Terminal
# 8                                London City Airport
# 9                      London City Airport (Airside)
#
#                            AddressLine2 AddressLine3  ...  \
# 0      Cherry Garden Street Rotherhithe     Charlton  ...
# 1                  South Benfleet Essex               ...
# 2                               Tilbury     Charlton  ...
# 3                         Tilbury Essex               ...
# 4                                London               ...
# 5                                London               ...
# 6                                London               ...
# 7  London City AirportRoyal DocksLondon               ...
# 8                     Silvertown London               ...
# 9                                London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': {'$toDouble': '$geocode.longitud...
# 1  {'longitude': {'$toDouble': '$geocode.longitud...
# 2  {'longitude': {'$toDouble': '$geocode.longitud...
# 3  {'longitude': {'$toDouble': '$geocode.longitud...
# 4  {'longitude': {'$toDouble': '$geocode.longitud...
# 5  {'longitude': {'$toDouble': '$geocode.longitud...
# 6  {'longitude': {'$toDouble': '$geocode.longitud...
# 7  {'longitude': {'$toDouble': '$geocode.longitud...
# 8  {'longitude': {'$toDouble': '$geocode.longitud...
# 9  {'longitude': {'$toDouble': '$geocode.longitud...
#
#       Distance NewRatingPending  \
# 0  4627.873179            False
# 1  4631.968418            False
# 2  4636.846754            False
# 3  4636.847650            False
# 4  4640.460834            False
# 5  4648.301822            False
# 6  4649.173485            False
# 7  4649.188826            False
# 8  4649.188850            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Latitude and logitude were found to be objects,convert latitude and longitude to numeric values
update_result = establishments.update_many(
    {'geocode.latitude': {'$exists': True}},
    [
        {'$set': {'geocode.latitude': {'$convert': {'input': '$geocode.latitude', 'to': 'double', 'onError': 0}}}},
        {'$set': {'geocode.longitude': {'$convert': {'input': '$geocode.longitude', 'to': 'double', 'onError': 0}}}}
    ]
)

# Check the update result
print(f"Number of documents updated: {update_result.modified_count}")
# Out:
# Number of documents updated: 38785

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 0
longitude = 0


query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}
sort = [('scores.Hygiene', 1)]

# Find the top 5 establishments with the specified criteria
top_establishments = establishments.find(query).sort(sort).limit(5)

# Print the results
print("Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score:")
for index, document in enumerate(top_establishments, start=1):
    print(f"\n#{index} - Hygiene Score: {document['scores']['Hygiene']}")
    pprint(document)
# Out:
# Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score:
#
# #1 - Hygiene Score: None
# {'AddressLine1': '42 North Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Lifeboat',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4592.005041613854,
#  'FHRSID': 511409,
#  'LocalAuthorityBusinessID': 'PI/000039931',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AF',
#  'RatingDate': '2020-07-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889474a11a2a0c91ff15'),
#  'geocode': {'latitude': 0, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/511409',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
# #2 - Hygiene Score: None
# {'AddressLine1': '24-26 Harbour Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Harbour Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.981553562698,
#  'FHRSID': 1023912,
#  'LocalAuthorityBusinessID': 'PI/000076188',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1QN',
#  'RatingDate': '2022-05-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889474a11a2a0c91ff0d'),
#  'geocode': {'latitude': 0, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1023912',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
# #3 - Hygiene Score: None
# {'AddressLine1': '5 Rendezvous Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Sweet Rendezvous',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.144852423555,
#  'FHRSID': 1292455,
#  'LocalAuthorityBusinessID': 'PI/000078049',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1EY',
#  'RatingDate': '2021-07-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889474a11a2a0c91ff41'),
#  'geocode': {'latitude': 0, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1292455',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
# #4 - Hygiene Score: None
# {'AddressLine1': 'Ground Floor Business Premises',
#  'AddressLine2': '2 Church Street',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Lucky Chip',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.124010103345,
#  'FHRSID': 1380216,
#  'LocalAuthorityBusinessID': 'PI/000078113',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1SE',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889474a11a2a0c91ff35'),
#  'geocode': {'latitude': 0, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1380216',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
# #5 - Hygiene Score: None
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Rock',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1423242,
#  'LocalAuthorityBusinessID': 'PI/000078141',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6595889474a11a2a0c91fee2'),
#  'geocode': {'latitude': 0, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423242',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(top_establishments)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Create the pipeline
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": SON([("count", -1)])}
]

# Execute the pipeline and retrieve the result
result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"Number of documents in each Local Authority area with a hygiene score of 0:")

# Print the first 10 results
for index, document in enumerate(result, start=1):
    print(f"\n#{index} - Local Authority: {document['_id']}")
    print(f"   Number of Establishments: {document['count']}")
# Out:
# Number of documents in each Local Authority area with a hygiene score of 0:
#
# #1 - Local Authority: Thanet
#    Number of Establishments: 1130
#
# #2 - Local Authority: Greenwich
#    Number of Establishments: 882
#
# #3 - Local Authority: Maidstone
#    Number of Establishments: 713
#
# #4 - Local Authority: Newham
#    Number of Establishments: 711
#
# #5 - Local Authority: Swale
#    Number of Establishments: 686
#
# #6 - Local Authority: Chelmsford
#    Number of Establishments: 680
#
# #7 - Local Authority: Medway
#    Number of Establishments: 672
#
# #8 - Local Authority: Bexley
#    Number of Establishments: 607
#
# #9 - Local Authority: Southend-On-Sea
#    Number of Establishments: 586
#
# #10 - Local Authority: Tendring
#    Number of Establishments: 542
#
# #11 - Local Authority: Colchester
#    Number of Establishments: 498
#
# #12 - Local Authority: Tunbridge Wells
#    Number of Establishments: 491
#
# #13 - Local Authority: Folkestone and Hythe
#    Number of Establishments: 480
#
# #14 - Local Authority: Eastbourne
#    Number of Establishments: 478
#
# #15 - Local Authority: Hastings
#    Number of Establishments: 464
#
# #16 - Local Authority: Bromley
#    Number of Establishments: 460
#
# #17 - Local Authority: Ashford
#    Number of Establishments: 427
#
# #18 - Local Authority: Havering
#    Number of Establishments: 397
#
# #19 - Local Authority: Dartford
#    Number of Establishments: 383
#
# #20 - Local Authority: Braintree
#    Number of Establishments: 382
#
# #21 - Local Authority: Basildon
#    Number of Establishments: 362
#
# #22 - Local Authority: Gravesham
#    Number of Establishments: 339
#
# #23 - Local Authority: Tonbridge and Malling
#    Number of Establishments: 325
#
# #24 - Local Authority: Thurrock
#    Number of Establishments: 313
#
# #25 - Local Authority: Barking and Dagenham
#    Number of Establishments: 301
#
# #26 - Local Authority: Canterbury City
#    Number of Establishments: 298
#
# #27 - Local Authority: Brentwood
#    Number of Establishments: 285
#
# #28 - Local Authority: Castle Point
#    Number of Establishments: 281
#
# #29 - Local Authority: Harlow
#    Number of Establishments: 274
#
# #30 - Local Authority: Uttlesford
#    Number of Establishments: 251
#
# #31 - Local Authority: Lewes
#    Number of Establishments: 250
#
# #32 - Local Authority: Sevenoaks
#    Number of Establishments: 223
#
# #33 - Local Authority: Maldon
#    Number of Establishments: 197
#
# #34 - Local Authority: East Hertfordshire
#    Number of Establishments: 189
#
# #35 - Local Authority: Rochford
#    Number of Establishments: 187
#
# #36 - Local Authority: Redbridge
#    Number of Establishments: 182
#
# #37 - Local Authority: Epping Forest
#    Number of Establishments: 180
#
# #38 - Local Authority: East Suffolk
#    Number of Establishments: 159
#
# #39 - Local Authority: Waltham Forest
#    Number of Establishments: 110
#
# #40 - Local Authority: Babergh
#    Number of Establishments: 97
#
# #41 - Local Authority: Wealden
#    Number of Establishments: 93
#
# #42 - Local Authority: Rother
#    Number of Establishments: 80
#
# #43 - Local Authority: Lewisham
#    Number of Establishments: 65
#
# #44 - Local Authority: Tandridge
#    Number of Establishments: 42
#
# #45 - Local Authority: City of London Corporation
#    Number of Establishments: 28
#
# #46 - Local Authority: Ipswich
#    Number of Establishments: 21
#
# #47 - Local Authority: Tower Hamlets
#    Number of Establishments: 9
#
# #48 - Local Authority: North Hertfordshire
#    Number of Establishments: 6
#
# #49 - Local Authority: Mid Sussex
#    Number of Establishments: 5
#
# #50 - Local Authority: Kensington and Chelsea
#    Number of Establishments: 1
#
# #51 - Local Authority: Dorset
#    Number of Establishments: 1
#
# #52 - Local Authority: North Norfolk
#    Number of Establishments: 1
#
# #53 - Local Authority: Broxbourne
#    Number of Establishments: 1
#
# #54 - Local Authority: Sunderland
#    Number of Establishments: 1
#
# #55 - Local Authority: Reading
#    Number of Establishments: 1

# %%
# Convert the result to a Pandas DataFrame
df_result = pd.DataFrame(result)

# Display the number of rows in the DataFrame
num_rows = len(df_result)
print(f"Number of rows in the DataFrame: {num_rows}")

# Display the first 10 rows of the DataFrame
df_result.head(10)
# Out:
# Number of rows in the DataFrame: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
